# %%
from pathlib import Path
import pandas as pd
import ast
from tqdm import tqdm

# %% [markdown]
# ### Data debugging

# %%
# feature_dir = Path('/lustre/groups/peng/datasets/histology_data/DACHS/features/Raw/Dachs_HistAuGAN_CTransPath/')
# clini_table =  Path('/lustre/groups/peng/datasets/histology_data/clini_tables/DACHS-CRC-DX_CLINI.xlsx')
# slide_csv = Path('/lustre/groups/peng/datasets/histology_data/clini_tables/DACHS-CRC-DX_SLIDE.csv')
feature_dir = Path('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/')
clini_table =  Path('/lustre/groups/peng/datasets/histology_data/clini_tables/FOXTROT-CRC-DX_CLINI.xlsx')
slide_csv = Path('/lustre/groups/peng/datasets/histology_data/clini_tables/FOXTROT-CRC-DX_resection_tumor_slide.csv')
target_labels = ['isMSIH']
clini_info= {}
categories = ['Not mut.', 'Mutat.', 'nonMSIH', 'MSIH', 'WT', 'MUT', 'wt', 'MT']

# %%
clini_df = pd.read_csv(clini_table, dtype=str) if Path(clini_table).suffix == '.csv' else pd.read_excel(
    clini_table, dtype=str)
slide_df = pd.read_csv(slide_csv, dtype=str)
df = clini_df.merge(slide_df, on='PATIENT')
# adapt dataframe to case sensitive clini tables
df = df.rename({
    'MSI': 'isMSIH',
    'BRAF': 'braf', 'BRAF_mutation': 'braf', 'braf_status': 'braf', 
    'KRAS': 'kras', 'kras_status': 'kras', 'KRAS_mutation': 'kras',
    'NRAS': 'nras', 'NRAS_mutation': 'nras',
    'Age': 'AGE'
}, axis=1)

# %%
clini_df
# Out:
#               Case PATIENT MMRStatus MLH_1 PMS_2 MSH_2 MSH_6   isMSIH  \
# 0     FOXTROT_1001    1001      pMMR     1     1     1     1  nonMSIH
# 1     FOXTROT_1002    1002      pMMR     1     1     1     1  nonMSIH
# 2     FOXTROT_1003    1003      pMMR     1     1     1     1  nonMSIH
# 3     FOXTROT_1004    1004      pMMR     1     1     1     1  nonMSIH
# 4     FOXTROT_1005    1005      pMMR     1     1     1     1  nonMSIH
# ...            ...     ...       ...   ...   ...   ...   ...      ...
# 1048  FOXTROT_2049    2049      pMMR     1     1     1     1  nonMSIH
# 1049  FOXTROT_2050    2050   UNKNOWN   NaN   NaN   NaN   NaN      NaN
# 1050  FOXTROT_2051    2051      dMMR     0     0     1     1     MSIH
# 1051  FOXTROT_2052    2052      pMMR     1     1     1     1  nonMSIH
# 1052  FOXTROT_2053    2053      pMMR     1     1     1     1  nonMSIH
#
#      x_TCD_tumour1_ x_TCD_tumour2_
# 0           41.9672            NaN
# 1           28.1139            NaN
# 2           18.5668            NaN
# 3           19.1638            NaN
# 4            8.4746            NaN
# ...             ...            ...
# 1048         35.461            NaN
# 1049             50            NaN
# 1050        21.7391            NaN
# 1051        16.0714            NaN
# 1052        47.9167            NaN
#
# [1053 rows x 10 columns]

# %%
slide_df
# Out:
#            FILENAME PATIENT   CLASSIFICATION
# 0     FOXROT_100103    1053  resection tumor
# 1     FOXROT_100104    1053  resection tumor
# 2     FOXROT_100107    1053  resection tumor
# 3     FOXROT_100110    1053  resection tumor
# 4     FOXROT_100114    1053  resection tumor
# ...             ...     ...              ...
# 6006   FOXROT_99834    1027  resection tumor
# 6007   FOXROT_99835    1054  resection tumor
# 6008   FOXROT_99845    1028  resection tumor
# 6009   FOXROT_99856    1028  resection tumor
# 6010   FOXROT_99878    1028  resection tumor
#
# [6011 rows x 3 columns]

# %%
slide_df.PATIENT.nunique()
# Out:
# 869

# %%
# remove columns not in target_labels
for key in df.columns:
    if key not in target_labels + ['PATIENT', 'SLIDE', 'FILENAME', *list(clini_info.keys())]:
        df.drop(key, axis=1, inplace=True)
# remove rows/slides with non-valid labels
for target in target_labels:
    df = df[df[target].isin(categories)]

# %%
# h5s = set(feature_dir.glob('**/*.h5'))
h5s = set(Path('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath').glob('**/*.h5'))

# %%
h5s
# Out:
# {PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1300_to_1499/1481_wMacro/FOXROT_311488.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1638_wMacro/FOXROT_282675.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1200_to_1299/1207_wMacro/FOXROT_148804.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1531_wMacro/FOXROT_240018.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1300_to_1499/1431/FOXROT_210564.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1000_to_1099/1096_wMacro/FOXROT_119019.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1200_to_1299/1222/FOXROT_435792.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1200_to_1299/1274_wMacro/FOXROT_180386.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1000_to_1099/1045_wMacro/FOXROT_95806.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1580_wMacro/FOXROT_248514.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1697/FOXROT_432643.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1200_to_1299/1252/FOXROT_206326.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1000_to_1099/1089_wMacro/FOXROT_113981.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1100_to_1199/1161_wMacro/FOXROT_140490.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1300_to_1499/1317_wMacro/FOXROT_177036.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1000_to_1099/1091/FOXROT_129747.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1675/FOXROT_316120.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1598/FOXROT_269524.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1300_to_1499/1312_wMacro/FOXROT_186089.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1000_to_1099/1071_wMacro/FOXROT_108493.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1900_to_2053/2033/FOXROT_440064.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1100_to_1199/1164_wMacro/FOXROT_137416.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1900_to_2053/2011/FOXROT_363518.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1900_to_2053/2036/FOXROT_379510.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1900_to_2053/1938/FOXROT_362069.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1100_to_1199/1186_wMacro/FOXROT_137303.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1000_to_1099/1036_wMacro/FOXROT_96133.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1100_to_1199/1168_wMacro/FOXROT_135787.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1654_wMacro/FOXROT_289352.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1900_to_2053/1962/FOXROT_361732.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1000_to_1099/1026_wMacro/FOXROT_115141.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1200_to_1299/1221_wMacro/FOXROT_145970.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1200_to_1299/1271_wMacro/FOXROT_180420.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1300_to_1499/1488_wMacro/FOXROT_263106.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1541_wMacro/FOXROT_263059.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1687/FOXROT_376970.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1699_wMacro/FOXROT_305888.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1300_to_1499/1410_wMacro/FOXROT_210387.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1565/FOXROT_428705.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1531_wMacro/FOXROT_240015.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1000_to_1099/1029_wMacro/FOXROT_107787.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1100_to_1199/1121_wMacro/FOXROT_124510.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1000_to_1099/1076_wMacro/FOXROT_115105.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1000_to_1099/1027_wMacro/FOXROT_99661.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1300_to_1499/1342_wMacro/FOXROT_206861.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1000_to_1099/1011_wMacro/FOXROT_100526.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1900_to_2053/Immunos/FOXROT_MSH6/403873.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1200_to_1299/1210_wMacro/FOXROT_144470.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1502/FOXROT_337941.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1200_to_1299/1234/FOXROT_176890.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1100_to_1199/1176_wMacro/FOXROT_206139.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1300_to_1499/1483/FOXROT_261797.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1200_to_1299/1213/FOXROT_150610.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1698/FOXROT_334257.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1200_to_1299/1253_wMacro/FOXROT_153532.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1300_to_1499/1377/FOXROT_385045.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1000_to_1099/1023_wMacro/FOXROT_96940.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1900_to_2053/Immunos/FOXROT_TMAs/PMS-2/424971.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1900_to_2053/1980/FOXROT_353513.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1547/FOXROT_375872.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1200_to_1299/1229/FOXROT_157239.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1300_to_1499/1476_wMacro/FOXROT_233851.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1000_to_1099/1004_wMacro/FOXROT_97888.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1300_to_1499/1488_wMacro/FOXROT_263091.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1000_to_1099/1062_wMacro/FOXROT_99735.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1527_wMacro/FOXROT_237685.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1900_to_2053/1933/FOXROT_353145.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1612/FOXROT_289320.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1653/FOXROT_385050.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1200_to_1299/1280_wMacro/FOXROT_162060.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1617/FOXROT_289343.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1300_to_1499/1304_wMacro/FOXROT_176998.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/
h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1900_to_2053/1958/FOXROT_355068.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1500_to_1699/1575/FOXROT_269501.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1200_to_1299/1242_wMacro/FOXROT_153645.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1100_to_1199/1147/FOXROT_271632.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1900_to_2053/2006/FOXROT_363375.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1100_to_1199/1108/FOXROT_114414.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1900_to_2053/Immunos/FOXROT_MSH6/148507.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1300_to_1499/1325/FOXROT_339592.h5'),
#  PosixPath('/lustre/groups/peng/datasets/histology_data/FOXTROT/features/Macenko/FOXTROT-CRC-DX_macenko_ctranspath/TRANSFER_FOXTROT_1100_to_1199/1144_wMacro/FOXROT_135909.h5'),
#  ...}

# %% [markdown]
# ### Create slide-csv for cohort

# %%
feature_dir = Path('/lustre/groups/peng/datasets/histology_data/MCO-CRC-DX/features/Macenko/CTransPath')

# %%
h5s = set(feature_dir.glob('**/*.h5'))

# %%
filenames = [h5.stem for h5 in h5s]

# %%
names = pd.DataFrame(filenames, columns=['ParentSpecimen'])

# %%
names.to_csv('filenames.csv')

# %%
names
# Out:
#      ParentSpecimen
# 0           MCO5488
# 1           MCO5424
# 2           MCO4095
# 3           MCO2273
# 4           MCO0821
# ...             ...
# 1610        MCO5627
# 1611        MCO2291
# 1612        MCO5562
# 1613        MCO2996
# 1614        MCO4125
#
# [1615 rows x 1 columns]

# %%
mappings = pd.read_csv('MCO_slide_large.csv')
# Out:
# /tmp/ipykernel_1257418/2224843216.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   mappings = pd.read_csv('MCO_slide_large.csv')

# %%
mappings = mappings.drop('Unnamed: 2', axis=1)

# %%
mappings = mappings.dropna()

# %%
mappings
# Out:
#        PATIENT ParentSpecimen
# 0       4809.0      MCO100003
# 1       4809.0      MCO100003
# 2       4809.0      MCO100003
# 3       4809.0      MCO100003
# 4       4809.0      MCO100003
# ...        ...            ...
# 19164    303.0        MCO9995
# 19165    303.0        MCO9995
# 19166    303.0        MCO9995
# 19167    303.0        MCO9995
# 19168    303.0        MCO9995
#
# [19169 rows x 2 columns]

# %%
df = mappings.merge(names, on='ParentSpecimen')

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#       PATIENT ParentSpecimen
# 0       520.0        MCO1156
# 7      1672.0        MCO1164
# 14      523.0        MCO1181
# 21     1956.0        MCO1193
# 28     1963.0        MCO1209
# ...       ...            ...
# 4584   5119.0        MCO6226
# 4589   5125.0        MCO6232
# 4594   5126.0        MCO6233
# 4599   5128.0        MCO6235
# 4604   5131.0        MCO6238
#
# [799 rows x 2 columns]

# %%
df.PATIENT = df.PATIENT.astype(int)

# %%
df = df.reset_index()

# %%
df = df.drop('index', axis=1)

# %%
df
# Out:
#      PATIENT ParentSpecimen
# 0        520        MCO1156
# 1       1672        MCO1164
# 2        523        MCO1181
# 3       1956        MCO1193
# 4       1963        MCO1209
# ..       ...            ...
# 794     5119        MCO6226
# 795     5125        MCO6232
# 796     5126        MCO6233
# 797     5128        MCO6235
# 798     5131        MCO6238
#
# [799 rows x 2 columns]

# %%
df.to_csv('MCO-CRC-DX_slide.csv')

# %% [markdown]
# ### Create slide csv for MCO

# %%
clini = pd.read_excel('MCO-CRC-DX_clini_full.xlsx')

# %%
clini
# Out:
#       PATIENT  5yOS_E  5yOS  5yDSS_E FILENAME  OS  OS_E  \
# 0           8       0    59        0  MCO3966  59     0
# 1          12       1    44        1  MCO3968  44     1
# 2          13       1    22        0  MCO3969  22     1
# 3          14       1     9        1  MCO3970   9     1
# 4          17       0    59        0  MCO3973  59     0
# ...       ...     ...   ...      ...      ...  ..   ...
# 1390     5125       0    59        0  MCO6232  59     0
# 1391     5126       0    59        0  MCO6233  59     0
# 1392     5128       0    59        0  MCO6235  59     0
# 1393     5129       0    59        0  MCO6236  59     0
# 1394     5131       0    59        0  MCO6238  59     0
#
#                                              slide_path         SCORE  \
# 0     [Path('/home/xjiang/crc_surv_path/features/Nor... -3.255808e-02
# 1     [Path('/home/xjiang/crc_surv_path/features/Nor... -5.048414e-02
# 2     [Path('/home/xjiang/crc_surv_path/features/Nor... -1.474705e+07
# 3     [Path('/home/xjiang/crc_surv_path/features/Nor... -4.854023e-01
# 4     [Path('/home/xjiang/crc_surv_path/features/Nor...  3.359147e-01
# ...                                                 ...           ...
# 1390  [Path('/home/xjiang/crc_surv_path/features/Nor...  8.634378e-01
# 1391  [Path('/home/xjiang/crc_surv_path/features/Nor...  2.331220e-02
# 1392  [Path('/home/xjiang/crc_surv_path/features/Nor... -1.875084e-01
# 1393  [Path('/home/xjiang/crc_surv_path/features/Nor... -4.870297e-01
# 1394  [Path('/home/xjiang/crc_surv_path/features/Nor... -1.022755e+07
#
#      Lifetime Vital Status  ... Radiotherapy Treatment Type  \
# 0                    Alive  ...                         NaN
# 1                     Dead  ...                         NaN
# 2                     Dead  ...                         NaN
# 3                     Dead  ...                         NaN
# 4                    Alive  ...                         NaN
# ...                    ...  ...                         ...
# 1390                 Alive  ...                         NaN
# 1391                 Alive  ...                         NaN
# 1392                 Alive  ...                         NaN
# 1393                 Alive  ...                         NaN
# 1394                 Alive  ...                         NaN
#
#       Therapeutic Radiotherapy Dose Given Surgery Target Site (ICD-O-3)  \
# 0                                 Unknown        C18.6 Descending colon
# 1                                 Unknown        C18.6 Descending colon
# 2                          Not Applicable                   C18.0 Cecum
# 3                                 Unknown        C18.4 Transverse colon
# 4                                 Unknown           C18.7 Sigmoid colon
# ...                                   ...                           ...
# 1390                              Unknown             C20.9 Rectum, NOS
# 1391                       Not Applicable           C18.7 Sigmoid colon
# 1392                       Not Applicable        C18.4 Transverse colon
# 1393                                  Yes             C20.9 Rectum, NOS
# 1394                       Not Applicable        C18.4 Transverse colon
#
#      Surgical Procedure for Cancer Unnamed: 0_y       MSI adjTreat_new  \
# 0                              NaN          0.0    Stable          1.0
# 1                              NaN          1.0    Stable          1.0
# 2                              NaN          2.0    Stable          0.0
# 3                              NaN          3.0  Unstable          1.0
# 4                              NaN          4.0    Stable          1.0
# ...                            ...          ...       ...          ...
# 1390        Low Anterior resection       1468.0    Stable          1.0
# 1391                           NaN       1469.0    Stable          1.0
# 1392                           NaN       1470.0    Stable          0.0
# 1393        Low Anterior resection       1471.0    Stable          0.0
# 1394                           NaN       1472.0    Stable          0.0
#
#      Lymph Nodes(Tested)_new Lymph Nodes(Positive)_new N012
# 0                         14                         8   N2
# 1                         13                         3   N1
# 2                          2                         0   N0
# 3                         17                         6   N2
# 4                         16                         6   N2
# ...                      ...                       ...  ...
# 1390                      14                         0   N0
# 1391                      11                         1   N1
# 1392                      14                         0   N0
# 1393                      27                         0   N0
# 1394                      50                         0   N0
#
# [1395 rows x 54 columns]

# %%
slide = clini[['PATIENT', 'slide_path']]

# %%
slide
# Out:
#       PATIENT                                         slide_path
# 0           8  [Path('/home/xjiang/crc_surv_path/features/Nor...
# 1          12  [Path('/home/xjiang/crc_surv_path/features/Nor...
# 2          13  [Path('/home/xjiang/crc_surv_path/features/Nor...
# 3          14  [Path('/home/xjiang/crc_surv_path/features/Nor...
# 4          17  [Path('/home/xjiang/crc_surv_path/features/Nor...
# ...       ...                                                ...
# 1390     5125  [Path('/home/xjiang/crc_surv_path/features/Nor...
# 1391     5126  [Path('/home/xjiang/crc_surv_path/features/Nor...
# 1392     5128  [Path('/home/xjiang/crc_surv_path/features/Nor...
# 1393     5129  [Path('/home/xjiang/crc_surv_path/features/Nor...
# 1394     5131  [Path('/home/xjiang/crc_surv_path/features/Nor...
#
# [1395 rows x 2 columns]

# %%
for i in tqdm(range(len(slide))):
    # slide.slide_path[i] = 
    s = slide.slide_path[i]
    s = s.replace('Path(', '').replace(')', '')  # remove the 'Path()' function calls
    path_strs = ast.literal_eval(s)  # evaluate the resulting string

    # convert strings back to Path() objects
    path_list = [Path(x) for x in path_strs]
    slide.slide_path[i] = path_list
# Out:
#   0%|          | 0/1395 [00:00<?, ?it/s]/tmp/ipykernel_335047/1805378177.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   slide.slide_path[i] = path_list
# 100%|██████████| 1395/1395 [00:12<00:00, 114.56it/s]

# %%
slide = slide.explode('slide_path')

# %%
slide = slide.reset_index()

# %%
slide.slide_path[0]
# Out:
# PosixPath('/home/xjiang/crc_surv_path/features/Norm/MCO-CRC-DX/RetCCL/MCO3966.h5')

# %%
for i in tqdm(range(len(slide))):
    slide.slide_path[i] = slide.slide_path[i].stem
# Out:
#   0%|          | 0/1476 [00:00<?, ?it/s]/tmp/ipykernel_335047/2660812604.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   slide.slide_path[i] = slide.slide_path[i].stem
# 100%|██████████| 1476/1476 [00:06<00:00, 227.33it/s]

# %%
slide
# Out:
#       index  PATIENT slide_path
# 0         0        8    MCO3966
# 1         1       12    MCO3968
# 2         2       13    MCO3969
# 3         3       14    MCO3970
# 4         4       17    MCO3973
# ...     ...      ...        ...
# 1471   1390     5125    MCO6232
# 1472   1391     5126    MCO6233
# 1473   1392     5128    MCO6235
# 1474   1393     5129    MCO6236
# 1475   1394     5131    MCO6238
#
# [1476 rows x 3 columns]

# %%
slide = slide.drop('index', axis=1)

# %%
slide = slide.rename({'slide_path': 'FILENAME'}, axis=1)

# %%
slide.keys()
# Out:
# Index(['PATIENT', 'FILENAME'], dtype='object')

# %%
slide.to_csv('MCO-CRC-DX_slide.csv', index=False)

# %%
test = pd.read_csv('MCO-CRC-DX_slide.csv')

# %%
test
# Out:
#       PATIENT FILENAME
# 0           8  MCO3966
# 1          12  MCO3968
# 2          13  MCO3969
# 3          14  MCO3970
# 4          17  MCO3973
# ...       ...      ...
# 1471     5125  MCO6232
# 1472     5126  MCO6233
# 1473     5128  MCO6235
# 1474     5129  MCO6236
# 1475     5131  MCO6238
#
# [1476 rows x 2 columns]

# %% [markdown]
# ### Add clinical values such as BRAF and KRAS

# %%
exp = pd.read_excel('JJ_MCO_Experimental_Full_Raw_2021.xlsx')
exp = exp.rename({'Patient_ID': 'PATIENT'}, axis=1)
# Out:
# /home/haicu/sophia.wagner/miniconda3/envs/genalt/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
for key in exp.columns:
    if key not in ['PATIENT', 'Analyte', 'Result']:
        exp.drop(key, axis=1, inplace=True)

# %%
braf = exp.loc[exp['Analyte']=='BRAF']

# %%
braf
# Out:
#        PATIENT Analyte    Result
# 3            8    BRAF  Wildtype
# 4            8    BRAF  Wildtype
# 32          12    BRAF  Wildtype
# 33          12    BRAF  Wildtype
# 61          13    BRAF  Wildtype
# ...        ...     ...       ...
# 46196     5128    BRAF  Wildtype
# 46220     5129    BRAF  Wildtype
# 46221     5129    BRAF  Wildtype
# 46245     5131    BRAF  Wildtype
# 46246     5131    BRAF  Wildtype
#
# [3033 rows x 3 columns]

# %%
braf.Result.unique()
# Out:
# array(['Wildtype', 'Mutated c.1799T>A (V600E)', 'Not available'],
#       dtype=object)

# %%
braf = braf.rename({'Result': 'BRAF'}, axis=1)
braf = braf.replace({'Mutated c.1799T>A (V600E)': 'MUT'})
braf = braf.replace({'Wildtype': 'WT'})
braf = braf.replace({'Not available': 'NaN'})

# %%
braf = braf.drop('Analyte', axis=1)
braf = braf.drop_duplicates()
braf = braf.reset_index(drop=True)

# %%
braf
# Out:
#       PATIENT BRAF
# 0           8   WT
# 1          12   WT
# 2          13   WT
# 3          14  MUT
# 4          17   WT
# ...       ...  ...
# 1511     5125   WT
# 1512     5126   WT
# 1513     5128   WT
# 1514     5129   WT
# 1515     5131   WT
#
# [1516 rows x 2 columns]

# %%
clini_braf = clini.merge(braf, on='PATIENT')

# %%
clini_braf
# Out:
#       PATIENT  5yOS_E  5yOS  5yDSS_E FILENAME  OS  OS_E  \
# 0           8       0    59        0  MCO3966  59     0
# 1          12       1    44        1  MCO3968  44     1
# 2          13       1    22        0  MCO3969  22     1
# 3          14       1     9        1  MCO3970   9     1
# 4          17       0    59        0  MCO3973  59     0
# ...       ...     ...   ...      ...      ...  ..   ...
# 1431     5125       0    59        0  MCO6232  59     0
# 1432     5126       0    59        0  MCO6233  59     0
# 1433     5128       0    59        0  MCO6235  59     0
# 1434     5129       0    59        0  MCO6236  59     0
# 1435     5131       0    59        0  MCO6238  59     0
#
#                                              slide_path         SCORE  \
# 0     [Path('/home/xjiang/crc_surv_path/features/Nor... -3.255808e-02
# 1     [Path('/home/xjiang/crc_surv_path/features/Nor... -5.048414e-02
# 2     [Path('/home/xjiang/crc_surv_path/features/Nor... -1.474705e+07
# 3     [Path('/home/xjiang/crc_surv_path/features/Nor... -4.854023e-01
# 4     [Path('/home/xjiang/crc_surv_path/features/Nor...  3.359147e-01
# ...                                                 ...           ...
# 1431  [Path('/home/xjiang/crc_surv_path/features/Nor...  8.634378e-01
# 1432  [Path('/home/xjiang/crc_surv_path/features/Nor...  2.331220e-02
# 1433  [Path('/home/xjiang/crc_surv_path/features/Nor... -1.875084e-01
# 1434  [Path('/home/xjiang/crc_surv_path/features/Nor... -4.870297e-01
# 1435  [Path('/home/xjiang/crc_surv_path/features/Nor... -1.022755e+07
#
#      Lifetime Vital Status  ... Therapeutic Radiotherapy Dose Given  \
# 0                    Alive  ...                             Unknown
# 1                     Dead  ...                             Unknown
# 2                     Dead  ...                      Not Applicable
# 3                     Dead  ...                             Unknown
# 4                    Alive  ...                             Unknown
# ...                    ...  ...                                 ...
# 1431                 Alive  ...                             Unknown
# 1432                 Alive  ...                      Not Applicable
# 1433                 Alive  ...                      Not Applicable
# 1434                 Alive  ...                                 Yes
# 1435                 Alive  ...                      Not Applicable
#
#       Surgery Target Site (ICD-O-3) Surgical Procedure for Cancer  \
# 0            C18.6 Descending colon                           NaN
# 1            C18.6 Descending colon                           NaN
# 2                       C18.0 Cecum                           NaN
# 3            C18.4 Transverse colon                           NaN
# 4               C18.7 Sigmoid colon                           NaN
# ...                             ...                           ...
# 1431              C20.9 Rectum, NOS        Low Anterior resection
# 1432            C18.7 Sigmoid colon                           NaN
# 1433         C18.4 Transverse colon                           NaN
# 1434              C20.9 Rectum, NOS        Low Anterior resection
# 1435         C18.4 Transverse colon                           NaN
#
#      Unnamed: 0_y       MSI adjTreat_new Lymph Nodes(Tested)_new  \
# 0             0.0    Stable          1.0                      14
# 1             1.0    Stable          1.0                      13
# 2             2.0    Stable          0.0                       2
# 3             3.0  Unstable          1.0                      17
# 4             4.0    Stable          1.0                      16
# ...           ...       ...          ...                     ...
# 1431       1468.0    Stable          1.0                      14
# 1432       1469.0    Stable          1.0                      11
# 1433       1470.0    Stable          0.0                      14
# 1434       1471.0    Stable          0.0                      27
# 1435       1472.0    Stable          0.0                      50
#
#      Lymph Nodes(Positive)_new N012 BRAF
# 0                            8   N2   WT
# 1                            3   N1   WT
# 2                            0   N0   WT
# 3                            6   N2  MUT
# 4                            6   N2   WT
# ...                        ...  ...  ...
# 1431                         0   N0   WT
# 1432                         1   N1   WT
# 1433                         0   N0   WT
# 1434                         0   N0   WT
# 1435                         0   N0   WT
#
# [1436 rows x 55 columns]

# %%
kras = exp.loc[exp['Analyte']=='KRAS']

# %%
kras
# Out:
#        PATIENT Analyte                  Result
# 6            8    KRAS   Mutated (Codon 12/13)
# 7            8    KRAS  Mutated c.34G>T (G12C)
# 35          12    KRAS                Wildtype
# 36          12    KRAS                Wildtype
# 63          13    KRAS   Mutated (Codon 12/13)
# ...        ...     ...                     ...
# 46200     5128    KRAS                Wildtype
# 46224     5129    KRAS                Wildtype
# 46225     5129    KRAS                Wildtype
# 46249     5131    KRAS   Mutated (Codon 12/13)
# 46250     5131    KRAS  Mutated c.34G>T (G12C)
#
# [3042 rows x 3 columns]

# %%
kras.KRAS.unique()
# Out:
# array(['MUT', 'WT', 'NaN'], dtype=object)

# %%
kras = kras.rename({'Result': 'KRAS'}, axis=1)
kras = kras.replace({'Mutated (Codon 12/13)': 'MUT'})
kras = kras.replace({'Mutated c.34G>T (G12C)': 'MUT'})
kras = kras.replace({'Mutated c.38G>A (G13D)': 'MUT'})
kras = kras.replace({'Mutated c.35G>C (G12A)': 'MUT'})
kras = kras.replace({'Mutated c.35G>A (G12D)': 'MUT'})
kras = kras.replace({'Mutated c.35G>T (G12V)|Mutated c.38G>A (G13D) ': 'MUT'})
kras = kras.replace({'Mutated c.35G>T (G12V)': 'MUT'})
kras = kras.replace({'Mutated c.34G>A (G12S)': 'MUT'})
kras = kras.replace({'Mutated c.34G>C (G12R)': 'MUT'})
kras = kras.replace({'Mutated c.37G>T (G13C)': 'MUT'})
kras = kras.replace({'Mutated c.183A>C (Q61H) ': 'MUT'})
kras = kras.replace({'Mutated': 'MUT'})
kras = kras.replace({'Mutated c.38G>T (G13V)': 'MUT'})
kras = kras.replace({'Mutated c.34G>T (G12C) & Mutated c.35G>C (G12A) & Mutated c.38G>T (G13V)': 'MUT'})
kras = kras.replace({'Wildtype': 'WT'})
kras = kras.replace({'Not available': 'NaN'})

# %%
kras = kras.drop('Analyte', axis=1)
kras = kras.drop_duplicates()
kras = kras.reset_index(drop=True)

# %%
kras
# Out:
#       PATIENT KRAS
# 0           8  MUT
# 1          12   WT
# 2          13  MUT
# 3          14   WT
# 4          17  MUT
# ...       ...  ...
# 1516     5125  MUT
# 1517     5126   WT
# 1518     5128   WT
# 1519     5129   WT
# 1520     5131  MUT
#
# [1521 rows x 2 columns]

# %%
clini_braf_kras = clini_braf.merge(kras, on='PATIENT')

# %%
clini_braf_kras.to_excel('MCO-CRC-DX_clini_full_braf_kras.xlsx')

# %% [markdown]
# ### create csv table for MAINZ BIOPSIES

# %%
table = pd.read_csv('Liste_Slides_Sophia.csv')

# %%
patient = []
for p in table['Patient_ID']:
    patient_id = p.split('_Slide')[0]
    if patient_id not in patient:
        patient.append(patient_id)

# %%
clini = pd.DataFrame(patient, columns=['PATIENT'])

# %%
clini['isMSIH'] = 'NaN'

# %%
for i in range(len(clini)):
    clini.isMSIH[i] = table.loc[table['Patient_ID'] == clini.PATIENT[i] + '_Slide_1', ['MSS/MSI']].values[0][0]

# %%
clini.to_excel('MAINZ-BIOPSIES-CRC-DX_clini.xlsx')

# %%
slide = pd.DataFrame(table['Patient_ID'].values, columns=['FILENAME'])

# %%
slide['PATIENT'] = 'NaN'

# %%
for i in range(len(slide)):
    slide['PATIENT'][i] = slide['FILENAME'][i].split('_Slide')[0]

# %%
slide.to_csv('MAINZ-BIOPSIES-CRC-DX_slide.csv', index=False)

# %%
clini_path = Path('/lustre/groups/peng/datasets/histology_data/clini_tables/MAINZ-BIOPSIES-CRC-DX_clini.xlsx')

# %%
clini = pd.read_excel(clini_path)

# %%
clini.isMSIH = clini.isMSIH.replace({'MSS': 'nonMSIH'})

# %%
clini.isMSIH = clini.isMSIH.replace({'MSI': 'MSIH'})

# %%
clini.to_excel(clini_path)
